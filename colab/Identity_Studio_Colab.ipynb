# %% [markdown]
# # Identity Studio Colab Launcher
#
# Run all cells and wait for the final output with a public **Gradio URL**.
#
# This notebook is Colab-first and does not require Docker.

# %%
# !rm -rf /content/foocus_pro
# !git clone -b cursor/identity-studio-ed79 https://github.com/sunsideaspect/foocus_pro.git /content/foocus_pro
# %cd /content/foocus_pro
# !pip install -r colab/requirements.txt

# %%
# Optional: best-quality identity backend (roop + ArcFace scorer)
# Run this if you want max identity lock quality.
# !bash colab/setup_max_identity.sh /content/foocus_pro

# %%
# Optional: start local ArcFace similarity server (used by strict identity preset)
# !nohup python -m uvicorn colab.arcface_similarity_server:app --host 0.0.0.0 --port 8890 >/content/arcface.log 2>&1 &

# %%
# !python -m colab.launch_colab --share --port 7860

# %% [markdown]
# ## Backend mode
#
# Open **Foocus Adapter** in UI:
# - `mock` for smoke testing,
# - `http` for Foocus-compatible HTTP backend,
# - `cli` for Foocus CLI command.
#
# For strongest identity:
# - set preset to `max_identity_quality` (or `max_identity_vivid`),
# - click `Apply quality preset`,
# - upload a clean reference face image.
